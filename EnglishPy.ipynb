# %%
#! /usr/bin/env python
# -*- coding: Utf-8 -*-
import os, random, sys

def somme(liste):
    _somme = 0
    for i in liste:
        _somme = _somme + i
    return _somme
    
fichier = open("129 ever et never.txt",'r',encoding="utf-8")
                  
              
tab = fichier.readlines()
n=len(tab)
print(n)

poids = [0]*(n)


for i in range(n):
    choice = random.randrange(0,n)
    while (poids[choice]==1):
        choice = random.randrange(0,n)
    if (poids[choice]==0):
        
        print("ligne n° : ",choice+1,"\t Phrases réussies : ",somme(poids),"/",n)
        phrases = tab[choice].split('_')
        
        print('')
        print(phrases[1])
        sentence = input("trad? : ")
        if (len(sentence)==1 and sentence!='w'):
            sys.exit("Fin de partie")
        if (sentence=='w'):
            print("Je passe")
            sentence='je passe'
            continue
        while (sentence != str(phrases[0]) and sentence!='je passe') :
            print("perdu :\t\t",phrases[0])
            sentence = input("trad? :\t\t")
            if (sentence=='p'):
                print("Je passe")
                sentence='je passe'
                continue
        print("\n\t-----------------  OK  ---------------")
        poids[choice]=1
print("##### FIN DU FICHIER #####") 
fichier.close()
# Out:
# 14
# ligne n° :  4 	 Phrases réussies :  0 / 14
#
# C'est le plus beau film que j'ai jamais vu.
#
# trad? : It's the most beautiful movie I've ever seen.
# perdu :		 It's the most beautiful film I've ever seen.
# trad? :		It's the most beautiful film I've ever seen.
#
# 	-----------------  OK  ---------------
# ligne n° :  1 	 Phrases réussies :  1 / 14
#
# Est-ce que tu vas parfois au concert?
#
# trad? : Do you ever go to concerts?
#
# 	-----------------  OK  ---------------
# ligne n° :  11 	 Phrases réussies :  2 / 14
#
# Donne-moi un baiser! Jamais.
#
# trad? : Give me a kiss! Never.
#
# 	-----------------  OK  ---------------
# ligne n° :  9 	 Phrases réussies :  3 / 14
#
# Alice ne dit jamais merci.
#
# trad? : Alice never says thank you.
# perdu :		 Alice nver says thank you.
# trad? :		p
# Je passe
#
# 	-----------------  OK  ---------------
# ligne n° :  13 	 Phrases réussies :  4 / 14
#
# Jamais rien ne se passe ici.
#
# trad? : Nothing never happens here.
# perdu :		 Nothing ever happens here.
# trad? :		Nothing ever happens here.
#
# 	-----------------  OK  ---------------
# ligne n° :  14 	 Phrases réussies :  5 / 14
#
# Je ne lis presque jamais de romans.
#
# trad? : I hardly never read novels.
# perdu :		 I hardly ever read novels.
# trad? :		I hardly ever read novels.
#
# 	-----------------  OK  ---------------
# ligne n° :  8 	 Phrases réussies :  6 / 14
#
# Elle est plus belle que jamais.
#
# trad? : She's lovelier than ever.
#
# 	-----------------  OK  ---------------
# ligne n° :  7 	 Phrases réussies :  7 / 14
#
# Je t'aimerai toujours.
#
# trad? : I'll love you for ever.
#
# 	-----------------  OK  ---------------
# ligne n° :  6 	 Phrases réussies :  8 / 14
#
# Viens nous voir si jamais tu te trouves à Londres.
#
# trad? : Come to see us if you're ever in London.
# perdu :		 Come and see us if you are ever in London.
# trad? :		Come an see us if you are ever in London.
# perdu :		 Come and see us if you are ever in London.
# trad? :		Come and see us if you are ever in London.
#
# 	-----------------  OK  ---------------
# ligne n° :  5 	 Phrases réussies :  9 / 14
#
# C'était l'histoire la plus étonnante qu'elle eût jamais entendue.
#
# trad? : It was the most amazing story she've ever heard.
# perdu :		 It was the most amazing story she had ever heard.
# trad? :		It was the most amazing story she had ever heard.
#
# 	-----------------  OK  ---------------
# ligne n° :  2 	 Phrases réussies :  10 / 14
#
# Est-ce que tu es déjà allé en Ecosse?
#
# trad? : Have you ever been in Scotland?
# perdu :		 Have you ever been to Scotland?
# trad? :		Have you ever been to Scotland?
#
# 	-----------------  OK  ---------------
# ligne n° :  12 	 Phrases réussies :  11 / 14
#
# Je ne pensais pas que je arriverais jamais.
#
# trad? : I didn't think I ever came.
# perdu :		 I didn't think I would ever arrive.
# trad? :		I didn't think I would ever arrive.
#
# 	-----------------  OK  ---------------
# ligne n° :  3 	 Phrases réussies :  12 / 14
#
# Je joue parfois au tennis.
#
# trad? : I play sometimes tennis.
# perdu :		 I sometimes play tennis.
# trad? :		I sometimes play tennis.
#
# 	-----------------  OK  ---------------
# ligne n° :  10 	 Phrases réussies :  13 / 14
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9100/3649922816.py in <module>
#      29
#      30         print('')
# ---> 31         print(phrases[1])
#      32         sentence = input("trad? : ")
#      33         if (len(sentence)==1 and sentence!='w'):
#
# IndexError: list index out of range
